# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from analysis.scripts.experiment_helpers import *

# %%
exp2 = pd.read_json('analysis/data/experiments/run_20260528_190112.json')
runs = exp2["experiments"]

# 1. crunch
results = analyze_runs(runs)

# 2. print
print_grouped_results(results, by=('sf', 'bw'))
# Out:
#   skip SF=7 BW=125 started=2026-05-28T21:16: No columns to parse from file
# ── SF=5  BW=125  (n=15) ────────────────────────────────────────────────────────────────────────────
#    #    SF     BW    KP    KI  Nodes       Settle        Median(µs)         Std(µs)         %InLow
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    1     5    125    40    50      1      $4 ±0$,    $1.4 ±0.4iqr$,   $3.95 ±0.37$,   $6.6 ±0.0%$,
# ── SF=6  BW=125  (n=15) ────────────────────────────────────────────────────────────────────────────
#    #    SF     BW    KP    KI  Nodes       Settle        Median(µs)         Std(µs)         %InLow
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    1     6    125    40    50      1      $4 ±0$,    $0.6 ±0.6iqr$,   $3.50 ±0.81$,   $7.3 ±2.8%$,
# ── SF=7  BW=125  (n=14) ────────────────────────────────────────────────────────────────────────────
# ...

# %%
my_fig = plot_grouped_results(results, by=('sf', 'bw'), title="Measured delay per run by SF and BW")

# %%
oscillation_fig = plot_oscillation_traces(results, by=('sf', 'bw'), value_col='hardware_delay')
# Out:
# 5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 oscillation_fig = plot_oscillation_traces(results, by=('sf', 'bw'), value_col='hardware_delay')
# File ~/code/must-rs/analysis/scripts/experiment_helpers.py:328, in plot_oscillation_traces(results, by, value_col, skip_initial)
#     326 for r in group:
#     327     try:
# --> 328         df = pd.read_csv(r["hw_stats"])
#     329     except FileNotFoundError, pd.errors.EmptyDataError:
#     330         continue
# KeyError: 'hw_stats'
