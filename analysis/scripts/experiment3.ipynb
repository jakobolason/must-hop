# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from analysis.scripts.experiment_helpers import *

# %%
exp2 = pd.read_json('analysis/data/experiments/run_20260606_211237.json')
runs = exp2["experiments"]

results = analyze_runs(runs)

print_grouped_results(results, by=('tau',))
# Out:
# ── TAU=10  (n=10) ──────────────────────────────────────────────────────────────────────────────────
#    #    SF     BW    KP    KI  Nodes       Settle        Median(µs)         Std(µs)         %InLow
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    1     7    125    40    50      1     $40 ±0$,  $1.9 ±0.1i q r$,   $0.23 ±0.02$,   $2.4 ±0.0%$,
# ── TAU=15  (n=10) ──────────────────────────────────────────────────────────────────────────────────
#    #    SF     BW    KP    KI  Nodes       Settle        Median(µs)         Std(µs)         %InLow
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    1     7    125    26    33      1     $50 ±6$,  $1.9 ±0.0i q r$,   $0.35 ±0.03$,   $4.7 ±0.8%$,
# ── TAU=20  (n=10) ──────────────────────────────────────────────────────────────────────────────────
#    #    SF     BW    KP    KI  Nodes       Settle        Median(µs)         Std(µs)         %InLow
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    1     7    125    20    25      1     $40 ±7$,  $1.9 ±0.0i q r$,   $0.58 ±0.12$,   $6.3 ±1.4%$,
# ── TAU=30  (n=10) ──────────────────────────────────────────────────────────────────────────────────
#    #    SF     BW    KP    KI  Nodes       Settle        Median(µs)         Std(µs)         %InLow
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    1     7    125    13    16      1     $50 ±0$,  $2.9 ±0.1i q r$,   $2.49 ±0.43$,  $92.5 ±23.7%$,

# %%
my_fig = plot_grouped_results(results, by=('tau', ), title="Measured delay per run by heartbeat interval Tau")

# %%
oscillation_fig = plot_oscillation_traces(results, by=('tau', ), value_col='haHW delay mean ± std (µs)"rdware_delay')
