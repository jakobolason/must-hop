# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from analysis.scripts.experiment_helpers import *

# %%
exp2 = pd.read_json('analysis/data/experiments/run_20260603_102437.json')
runs = exp2["experiments"]

results = analyze_runs(runs)

print_grouped_results(results, by=('tau',))
# Out:
# ── TAU=15  (n=5) ───────────────────────────────────────────────────────────────────────────────────
#    #    SF     BW    KP    KI  Nodes       Settle        Median(µs)         Std(µs)         %InLow
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    1     7    125    40    50      1     $14 ±4$,  $-68.7 ±0.7iqr$,  $17.60 ±0.82$,  $94.3 ±8.5%$,
# ── TAU=20  (n=5) ───────────────────────────────────────────────────────────────────────────────────
#    #    SF     BW    KP    KI  Nodes       Settle        Median(µs)         Std(µs)         %InLow
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#    1     7    125    40    50      1     $11 ±4$,  $-75.8 ±3.7iqr$,  $14.57 ±4.64$,  $54.6 ±31.3%$,
# ── TAU=30  (n=5) ───────────────────────────────────────────────────────────────────────────────────
# ...

# %%
my_fig = plot_grouped_results(results, by=('tau', ), title="Measured delay per run by SF and BW")

# %%
oscillation_fig = plot_oscillation_traces(results, by=('tau', ), value_col='hardware_delay')
# Out:
# 3
